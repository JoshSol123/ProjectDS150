# %%
import pandas as pd
import numpy as np

print(f"Pandas version: {pd.__version__}")
# Out:
# Pandas version: 2.3.2

# %%
kwik_locations = pd.DataFrame(pd.read_excel('KwikData.xlsx'))
print(kwik_locations)
# Out:
#     Store List - Kwik Trip | Kwik Star         Unnamed: 1  \
# 0                         Store Number         Store Name
# 1                                  932     KWIK STAR #932
# 2                                 1186    KWIK STAR #1186
# 3                                  530  KWIK SPIRITS #530
# 4                                 1158    KWIK STAR #1158
# ..                                 ...                ...
# 919                                128     KWIK TRIP #128
# 920                                347     KWIK TRIP #347
# 921                                331     KWIK TRIP #331
# 922                                310     KWIK TRIP #310
# 923                                847     KWIK TRIP #847
#
#                   Unnamed: 2        Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                    Address              City      State        Zip
# 1    120 ADVENTURELAND DR NE           ALTOONA         IA      50009
# ...

# %%
wi_locations = kwik_locations[kwik_locations['Unnamed: 4'] == 'WI']
print(wi_locations)
# Out:
#     Store List - Kwik Trip | Kwik Star      Unnamed: 1          Unnamed: 2  \
# 403                                885  KWIK TRIP #885   301 ELDERBERRY RD
# 404                                774  KWIK TRIP #774       237 N MAIN ST
# 405                                802  KWIK TRIP #802       603 N MAIN ST
# 406                                828  KWIK TRIP #828    2367 SPOONER AVE
# 407                                208  KWIK TRIP #208  2929 MEADOWLARK LN
# ..                                 ...             ...                 ...
# 919                                128  KWIK TRIP #128     1111 LINCOLN ST
# 920                                347  KWIK TRIP #347       4611 8TH ST S
# 921                                331  KWIK TRIP #331      3030 PLOVER RD
# 922                                310  KWIK TRIP #310    2520 W GRAND AVE
# 923                                847  KWIK TRIP #847       321 BRIDGE ST
#
# ...
